# %%
# Updated Dataset Visualization Notebook for MARBLE Project
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from scipy import signal
import os
import random
from glob import glob
from typing import Dict, List, Tuple, Optional
import datetime
import traceback

# Import dataset classes from dataset_constructor
from dataset_constructor import RawDataset, BandpowerDataset, EventSegmentDataset

# %%
# Set display parameters
plt.rcParams['figure.figsize'] = (16, 10)
plt.rcParams['font.size'] = 12

# Find the latest datasets
def find_latest_datasets(datasets_dir='/home/honglab/leijiaxin/MARBLE/datasets'):
    """Find the latest datasets of each type"""
    raw_files = sorted(glob(os.path.join(datasets_dir, '*raw_dataset.npz')))
    bp_files = sorted(glob(os.path.join(datasets_dir, '*bandpower_dataset.npz')))
    event_files = sorted(glob(os.path.join(datasets_dir, '*event_segments_dataset.npz')))
    
    latest_raw = raw_files[-1] if raw_files else None
    latest_bp = bp_files[-1] if bp_files else None
    latest_event = event_files[-1] if event_files else None
    
    return latest_raw, latest_bp, latest_event

# Load the latest datasets
latest_raw, latest_bp, latest_event = find_latest_datasets()
print(f"Latest raw dataset: {os.path.basename(latest_raw) if latest_raw else 'None'}")
print(f"Latest bandpower dataset: {os.path.basename(latest_bp) if latest_bp else 'None'}")
print(f"Latest event segment dataset: {os.path.basename(latest_event) if latest_event else 'None'}")
# Out:
# Latest raw dataset: 20250419_130924_raw_dataset.npz
# Latest bandpower dataset: 20250419_130924_bandpower_dataset.npz
# Latest event segment dataset: 20250419_130924_event_segments_dataset.npz

# %%
# 1. Raw Dataset Visualization
# ==========================
# Load dataset using the RawDataset class
raw_dataset = RawDataset.load(latest_raw)

# Print dataset information
print("\nRaw Dataset:")
print(f"Number of chunks: {len(raw_dataset)}")

# Get sampling frequency
sfreq = raw_dataset.config.get('raw_dataset', {}).get('resample_freq', 1000)
print(f"Sampling frequency: {sfreq} Hz")

# Get a chunk of data - now returns lists
data_list, time_list, events_list = raw_dataset.get_batched_data(
    start_idx=0, 
    num_chunks=25,  # Get more chunks for a batch example
    batch_size=5,
    chunks_per_batch_item=5
)

# Print shapes to understand the structure
print(f"Number of batches: {len(data_list)}")
if data_list:
    print(f"Batch item shape: {data_list[0].shape}")
    print(f"Time array shape: {time_list[0].shape}")
    print(f"Events array shape: {events_list[0].shape if events_list[0] is not None else 'None'}")

# Use the first batch item for visualization
if data_list:
    chunk_data = data_list[0]
    chunk_time = time_list[0]
    chunk_events = events_list[0]
    
    # Determine number of channels - assume the smaller dimension is channels
    if chunk_data.shape[0] < chunk_data.shape[1]:
        n_channels = chunk_data.shape[0]
        chunk_data = chunk_data.T  # Transpose to make it (time, channels)
    else:
        n_channels = chunk_data.shape[1]
        
    # Reasonable check for number of channels
    if n_channels > 100:
        print(f"Warning: Detected {n_channels} channels, which seems high. Using first 6 channels for visualization.")
        n_channels = min(6, chunk_data.shape[1])
        
    print(f"Visualizing {n_channels} channels")

    chunk_time = chunk_time.squeeze()

    # Plot raw signals with event markers
    plt.figure(figsize=(18, 12))
    for ch_idx in range(n_channels):
        plt.subplot(n_channels, 1, ch_idx+1)
        plt.plot(chunk_time, chunk_data[:, ch_idx], 'k-', linewidth=0.8)
        
        # Mark events if available
        if chunk_events is not None:
            event_indices = np.where(chunk_events > 0)[0]
            if len(event_indices) > 0:
                event_times = chunk_time[event_indices]
                event_amplitudes = chunk_data[event_indices, ch_idx]
                plt.scatter(event_times, event_amplitudes, c='r', marker='*', s=100)
            
        plt.title(f"Channel {ch_idx+1}")
        plt.ylabel('Amplitude')
        if ch_idx == n_channels-1:
            plt.xlabel('Time (s)')

    plt.suptitle(f"Raw Data - First Batch Item", y=0.98)
    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.show()

    # Plot spectrogram for each channel
    plt.figure(figsize=(18, 12))
    for ch_idx in range(n_channels):
        plt.subplot(n_channels, 1, ch_idx+1)
        
        # Compute spectrogram
        # Ensure nperseg is appropriate for the data length
        nperseg = min(256, chunk_data.shape[0]//4)
        noverlap = nperseg // 2
        
        f, t, Sxx = signal.spectrogram(
            chunk_data[:, ch_idx], 
            fs=sfreq, 
            nperseg=nperseg, 
            noverlap=noverlap
        )
        
        # Plot spectrogram - handle complex values by taking magnitude
        Sxx_mag = np.abs(Sxx)
        # Add small constant to avoid log10(0)
        Sxx_mag = Sxx_mag + 1e-10
        # Convert to numpy array and ensure it's float type
        Sxx_mag = np.asarray(Sxx_mag, dtype=np.float64)
        # Apply log10 transformation
        log_Sxx = 10 * np.log10(Sxx_mag)
        plt.pcolormesh(t, f, log_Sxx, shading='gouraud', cmap='viridis')
        plt.title(f"Channel {ch_idx+1} - Spectrogram")
        plt.ylabel('Frequency (Hz)')
        plt.ylim(0, min(500, sfreq/2))  # Limit to reasonable frequencies
        
        if ch_idx == n_channels-1:
            plt.xlabel('Time (s)')
            
    plt.suptitle(f"Spectrograms - First Batch Item", y=0.98)
    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.colorbar(plt.cm.ScalarMappable(cmap='viridis'), ax=plt.gcf().axes)
    plt.show()
else:
    print("No data available in the raw dataset")


# 2. Bandpower Dataset Visualization


# Load dataset using the BandpowerDataset class
bp_dataset = BandpowerDataset.load(latest_bp)

# Print dataset information
print("\nBandpower Dataset:")
print(f"Number of chunks: {len(bp_dataset)}")

# Examine the dataset structure
print("Dataset attributes:", [attr for attr in dir(bp_dataset) 
                                if not attr.startswith('_') and not callable(getattr(bp_dataset, attr))])

# Check if bands attribute exists
if hasattr(bp_dataset, 'bands'):
    available_bands = list(bp_dataset.bands.keys())
    print(f"Available bands: {available_bands}")
    
    # Visualize each band
    for band_name in available_bands:
        
        # Get data for the current band - now returns lists
        band_data_list, band_time_list, band_events_list = bp_dataset.get_batched_data(
            band_name=band_name, 
            start_idx=0, 
            num_chunks=25,
            batch_size=5,
            chunks_per_batch_item=5
        )
        
        # Print shapes to understand the structure
        print(f"Band {band_name} - Number of batches: {len(band_data_list)}")
        
        if band_data_list and len(band_data_list) > 0:
            print(f"Band data shape for {band_name}: {band_data_list[0].shape}")
            
            # Use the first batch item for visualization
            band_data = band_data_list[0]
            band_day_night = band_time_list[0] if band_time_list else None
            band_events = band_events_list[0] if band_events_list else None
            
            # Determine number of channels - assume the smaller dimension is channels
            if band_data.shape[0] < band_data.shape[1]:
                n_channels = band_data.shape[0]
                band_data = band_data.T  # Transpose to make it (time, channels)
            else:
                n_channels = band_data.shape[1]
                
            # Reasonable check for number of channels
            if n_channels > 100:
                print(f"Warning: Detected {n_channels} channels, which seems high. Using first 6 channels for visualization.")
                n_channels = min(6, band_data.shape[1])
                
            print(f"Visualizing {n_channels} channels for {band_name} band")
            
            # Create time array based on config
            window_size_ms = bp_dataset.config.get('bandpower', {}).get('window_size_ms', 100)
            overlap = bp_dataset.config.get('bandpower', {}).get('overlap', 0.5)
            effective_step_ms = window_size_ms * (1 - overlap)
            time_array = np.arange(band_data.shape[0]) * (effective_step_ms / 1000)
            
            # Plot band power
            plt.figure(figsize=(18, 12))
            for ch_idx in range(n_channels):
                plt.subplot(n_channels, 1, ch_idx+1)
                plt.plot(time_array, band_data[:, ch_idx], 'k-', linewidth=0.8)
                
                # Mark events if available
                if band_events is not None:
                    event_indices = np.where(band_events > 0)[0]
                    if len(event_indices) > 0:
                        event_times = time_array[event_indices]
                        event_powers = band_data[event_indices, ch_idx]
                        plt.scatter(event_times, event_powers, c='r', marker='*', s=100)
                
                # Mark day/night if available
                if band_day_night is not None:
                    night_indices = np.where(band_day_night == 0)[0]
                    if len(night_indices) > 0:
                        night_ranges = []
                        start_idx = night_indices[0]
                        for i in range(1, len(night_indices)):
                            if night_indices[i] != night_indices[i-1] + 1:
                                night_ranges.append((start_idx, night_indices[i-1]))
                                start_idx = night_indices[i]
                        night_ranges.append((start_idx, night_indices[-1]))
                        
                        for start, end in night_ranges:
                            plt.axvspan(time_array[start], time_array[end], color='blue', alpha=0.1)
                
                plt.title(f"Channel {ch_idx+1}")
                plt.ylabel('Power')
                if ch_idx == n_channels-1:
                    plt.xlabel('Time (s)')
            
            plt.suptitle(f"Bandpower - {band_name} - First Batch Item", y=0.98)
            plt.tight_layout()
            plt.subplots_adjust(top=0.95)
            plt.show()
            
            print(f"Successfully visualized {band_name} band data")
        else:
            print(f"No data available for {band_name} band")
                
else:
    print("No 'bands' attribute found in the dataset")
    # Try direct data access with known band names from config
    bands_config = bp_dataset.config.get('bandpower', {}).get('bands', {})
    band_names = list(bands_config.keys())
    print(f"Trying bands from config: {band_names}")
    
    for band_name in band_names:
        # Get data for the current band - now returns lists
        band_data_list, band_time_list, band_events_list = bp_dataset.get_batched_data(
            band_name=band_name, 
            start_idx=0, 
            num_chunks=25,
            batch_size=5,
            chunks_per_batch_item=5
        )
        
        if band_data_list and len(band_data_list) > 0:
            print(f"Successfully retrieved {band_name} band data")
            print(f"Band data shape: {band_data_list[0].shape}")
            # Visualization code would go here
        else:
            print(f"No data available for {band_name} band")

# 3. Event Segment Dataset Visualization  
# =====================================
def plot_event_signal_and_tf(event_data, event_info, sfreq):
    """
    Plot the signal and time-frequency map for an event
    
    Parameters:
    -----------
    event_data : array
        The EEG data for the event (channels x time)
    event_info : dict
        Information about the event
    sfreq : float
        Sampling frequency
    """
    # Check data shape and transpose if needed (we want time x channels for plotting)
    if len(event_data.shape) == 1:
        # If data is 1D, reshape to 2D with 1 channel
        event_data_plot = event_data.reshape(1, -1).T
        n_channels = 1
    elif event_data.shape[0] > event_data.shape[1]:  # Likely (time x channels)
        n_channels = event_data.shape[1]
        event_data_plot = event_data
    else:  # Likely (channels x time)
        n_channels = event_data.shape[0]
        event_data_plot = event_data.T
    
    # Create figure with panels for each channel
    fig = plt.figure(figsize=(20, 4 * n_channels))
    gs = GridSpec(n_channels, 2, width_ratios=[1, 1.5])
    
    for ch_idx in range(n_channels):
        # Left panel: Signal
        ax1 = plt.subplot(gs[ch_idx, 0])
        times = np.arange(event_data_plot.shape[0]) / sfreq
        ax1.plot(times, event_data_plot[:, ch_idx])
        
        # Mark the event type
        event_type = event_info.get('event_type', 0)
        event_middle = len(times) // 2
        
        # Color code by event type
        if event_type == 1:
            color = 'r'  # Low band (type 1)
            label = "Low Band"
        elif event_type == 2:
            color = 'g'  # High band (type 2)
            label = "High Band"
        elif event_type == 3:
            color = 'b'  # Both bands (type 3)
            label = "Both Bands"
        else:
            color = 'k'
            label = "Unknown"
            
        ax1.axvline(times[event_middle], color=color, linestyle='--', label=label)
        ax1.legend()
        
        if ch_idx == 0:
            ax1.set_title(f"Event Type: {event_type} ({label})")
        ax1.set_ylabel(f'Ch {ch_idx+1} Amplitude')
        if ch_idx == n_channels-1:
            ax1.set_xlabel('Time (s)')
        
        # Right panel: Time-frequency map
        ax2 = plt.subplot(gs[ch_idx, 1])
        
        # Compute time-frequency map using spectrogram
        # Ensure nperseg is appropriate for the data length
        data_length = event_data_plot.shape[0]
        nperseg = min(256, data_length//4) if data_length > 20 else data_length-1
        nperseg = max(nperseg, 4)  # Ensure minimum size
        noverlap = max(nperseg // 2, 1)  # Ensure noverlap < nperseg
        
        try:
            f, t, Sxx = signal.spectrogram(event_data_plot[:, ch_idx], fs=sfreq, 
                                         nperseg=nperseg, noverlap=noverlap)
            
            # Plot time-frequency map - handle complex values by taking magnitude
            Sxx_mag = np.abs(Sxx)
            # Add small constant to avoid log10(0)
            Sxx_mag = Sxx_mag + 1e-10
            # Apply log10 transformation - ensure Sxx_mag is a numpy array with float type
            Sxx_mag = np.asarray(Sxx_mag, dtype=np.float64)
            log_Sxx = 10 * np.log10(Sxx_mag)
            im = ax2.pcolormesh(t, f, log_Sxx, shading='gouraud', cmap='viridis')
            if ch_idx == 0:
                ax2.set_title('Time-Frequency Map')
            if ch_idx == n_channels-1:
                ax2.set_xlabel('Time (s)')
            ax2.set_ylabel(f'Ch {ch_idx+1} Freq (Hz)')
            
            # Frequency bands for event detection
            low_band = event_info.get('low_band', [80, 250])
            high_band = event_info.get('high_band', [250, 451])
            
            # Show frequency bands
            ax2.axhline(low_band[0], color='r', linestyle='-', alpha=0.5)
            ax2.axhline(low_band[1], color='r', linestyle='-', alpha=0.5)
            ax2.axhline(high_band[0], color='g', linestyle='-', alpha=0.5)
            ax2.axhline(high_band[1], color='g', linestyle='-', alpha=0.5)
            
            ax2.set_ylim(0, min(500, sfreq/2))  # Limit to frequencies of interest
        except Exception as e:
            ax2.text(0.5, 0.5, f"Error computing spectrogram: {str(e)}", 
                    horizontalalignment='center', verticalalignment='center')
    
    # Add colorbar if we have an image
    if 'im' in locals():
        cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
        cbar = plt.colorbar(im, cax=cbar_ax)
        cbar.set_label('Power/Frequency (dB/Hz)')
    
    plt.tight_layout()
    plt.subplots_adjust(right=0.9)
    return fig

# Load dataset using the static load method to avoid initialization issues
event_dataset = EventSegmentDataset.load(latest_event)

# Print dataset information
print("\nEvent Segment Dataset:")
print(f"Number of segments: {len(event_dataset)}")

# Examine dataset structure
print("Dataset attributes:", [attr for attr in dir(event_dataset) 
                            if not attr.startswith('_') and not callable(getattr(event_dataset, attr))])

# Get metadata from the dataset
metadata = event_dataset.metadata
print(f"Metadata keys: {list(metadata.keys())}")

# Get event detection parameters
event_detection = metadata.get('event_detection', {})
print(f"Event detection bands: Low={event_detection.get('low_band')}, High={event_detection.get('high_band')}")

# Get segment info
segment_info = metadata.get('segment_info', [])
print(f"Number of segments in metadata: {len(segment_info)}")

# Extract event types from segment info
event_types = [info.get('event_type', 0) for info in segment_info]
event_type_counts = {1: 0, 2: 0, 3: 0}
for event_type in event_types:
    if event_type in event_type_counts:
        event_type_counts[event_type] += 1

print(f"Event type counts from metadata: {event_type_counts}")

# Get batched data from the event dataset
data_list, time_list, events_list = event_dataset.get_batched_data(
    start_idx=0, 
    num_chunks=25,
    batch_size=5,
    chunks_per_batch_item=5
)

# Print shapes to understand the structure
print(f"Event dataset - Number of batches: {len(data_list)}")
if data_list:
    print(f"Batch item shape: {data_list[0].shape}")
    print(f"Time array shape: {time_list[0].shape if time_list[0] is not None else 'None'}")
    print(f"Events array shape: {events_list[0].shape if events_list[0] is not None else 'None'}")

# Visualize up to 3 segments from the first batch
if data_list and len(data_list) > 0:
    # Get the first batch
    batch_data = data_list[0]
    batch_times = time_list[0] if time_list else None
    batch_events = events_list[0] if events_list else None
    
    # Determine how many segments to visualize
    n_segments = min(3, batch_data.shape[0])
    
    for i in range(n_segments):
        # Get segment data
        segment_data = batch_data[i]
        segment_events = batch_events[i] if batch_events is not None else None
        
        print(f"\nSegment {i+1} shape: {segment_data.shape}")
        
        # Find event type (look for non-zero values in event labels)
        event_type = 0
        if segment_events is not None:
            # Find indices where event label is non-zero
            event_indices = np.where(segment_events > 0)[0]
            if len(event_indices) > 0:
                # Get the event type from the first non-zero index
                event_type = int(segment_events[event_indices[0]])
                print(f"Event type: {event_type}")
        
        # If no event type found in labels, try getting from segment info
        if event_type == 0 and i < len(segment_info):
            event_type = segment_info[i].get('event_type', 0)
            print(f"Event type from metadata: {event_type}")
        
        # Create event info for plotting
        event_info = {
            'event_type': event_type,
            'source': {},  # No longer have event_sources in the new format
            'low_band': event_detection.get('low_band', [80, 250]),
            'high_band': event_detection.get('high_band', [250, 451])
        }
        
        # Estimate sampling frequency from metadata or use default
        sfreq = metadata.get('sfreq', 1000)  # Default to 1000 Hz if not specified
        
        # Plot the segment
        fig = plot_event_signal_and_tf(segment_data, event_info, sfreq)
        plt.suptitle(f"Event Segment {i+1} - Type {event_type}", y=1.02)
        plt.tight_layout()
        plt.show()
else:
    print("No data available in the event dataset")
# Out:
# 2025-04-19 13:55:22,539 - dataset_constructor - INFO - Loading dataset using alternative format with 3267 chunks
# 2025-04-19 13:55:29,425 - dataset_constructor - INFO - Loaded raw dataset shapes:
# 2025-04-19 13:55:29,428 - dataset_constructor - INFO -   Chunk 0: shape (6, 10000)
# 2025-04-19 13:55:29,429 - dataset_constructor - INFO -   Chunk 1: shape (6, 10000)
# 2025-04-19 13:55:29,430 - dataset_constructor - INFO -   Chunk 2: shape (6, 10000)
# 2025-04-19 13:55:29,431 - dataset_constructor - INFO -   Chunk 3: shape (6, 10000)
# 2025-04-19 13:55:29,432 - dataset_constructor - INFO -   Chunk 4: shape (6, 10000)
# 2025-04-19 13:55:29,433 - dataset_constructor - INFO -   Chunk 5: shape (6, 10000)
# 2025-04-19 13:55:29,434 - dataset_constructor - INFO -   Chunk 6: shape (6, 10000)
# 2025-04-19 13:55:29,437 - dataset_constructor - INFO -   Chunk 7: shape (6, 10000)
# 2025-04-19 13:55:29,438 - dataset_constructor - INFO -   Chunk 8: shape (6, 10000)
# 2025-04-19 13:55:29,439 - dataset_constructor - INFO -   Chunk 9: shape (6, 10000)
# 2025-04-19 13:55:29,440 - dataset_constructor - INFO -   Chunk 10: shape (6, 10000)
# 2025-04-19 13:55:29,441 - dataset_constructor - INFO -   Chunk 11: shape (6, 10000)
# 2025-04-19 13:55:29,443 - dataset_constructor - INFO -   Chunk 12: shape (6, 10000)
# 2025-04-19 13:55:29,444 - dataset_constructor - INFO -   Chunk 13: shape (6, 10000)
# 2025-04-19 13:55:29,444 - dataset_constructor - INFO -   Chunk 14: shape (6, 10000)
# 2025-04-19 13:55:29,446 - dataset_constructor - INFO -   Chunk 15: shape (6, 10000)
# 2025-04-19 13:55:29,446 - dataset_constructor - INFO -   Chunk 16: shape (6, 10000)
# 2025-04-19 13:55:29,447 - dataset_constructor - INFO -   Chunk 17: shape (6, 10000)
# 2025-04-19 13:55:29,448 - dataset_constructor - INFO -   Chunk 18: shape (6, 10000)
# 2025-04-19 13:55:29,448 - dataset_constructor - INFO -   Chunk 19: shape (6, 10000)
# 2025-04-19 13:55:29,449 - dataset_constructor - INFO -   Chunk 20: shape (6, 10000)
# 2025-04-19 13:55:29,450 - dataset_constructor - INFO -   Chunk 21: shape (6, 10000)
# 2025-04-19 13:55:29,450 - dataset_constructor - INFO -   Chunk 22: shape (6, 10000)
# 2025-04-19 13:55:29,451 - dataset_constructor - INFO -   Chunk 23: shape (6, 10000)
# 2025-04-19 13:55:29,452 - dataset_constructor - INFO -   Chunk 24: shape (6, 10000)
# 2025-04-19 13:55:29,550 - dataset_constructor - INFO -   Chunk 214: shape (6, 10000)
# 2025-04-19 13:55:29,550 - dataset_constructor - INFO -   Chunk 215: shape (6, 10000)
# 2025-04-19 13:55:29,551 - dataset_constructor - INFO -   Chunk 216: shape (6, 10000)
# 2025-04-19 13:55:29,551 - dataset_constructor - INFO -   Chunk 217: shape (6, 10000)
# 2025-04-19 13:55:29,552 - dataset_constructor - INFO -   Chunk 218: shape (6, 10000)
# 2025-04-19 13:55:29,552 - dataset_constructor - INFO -   Chunk 219: shape (6, 10000)
# 2025-04-19 13:55:29,553 - dataset_constructor - INFO -   Chunk 220: shape (6, 10000)
# 2025-04-19 13:55:29,553 - dataset_constructor - INFO -   Chunk 221: shape (6, 10000)
# 2025-04-19 13:55:29,554 - dataset_constructor - INFO -   Chunk 222: shape (6, 10000)
# 2025-04-19 13:55:29,554 - dataset_constructor - INFO -   Chunk 223: shape (6, 10000)
# 2025-04-19 13:55:29,555 - dataset_constructor - INFO -   Chunk 224: shape (6, 10000)
# 2025-04-19 13:55:29,555 - dataset_constructor - INFO -   Chunk 225: shape (6, 10000)
# 2025-04-19 13:55:29,556 - dataset_constructor - INFO -   Chunk 226: shape (6, 10000)
# 2025-04-19 13:55:29,556 - dataset_constructor - INFO -   Chunk 227: shape (6, 10000)
# 2025-04-19 13:55:29,556 - dataset_constructor - INFO -   Chunk 228: shape (6, 10000)
# 2025-04-19 13:55:29,557 - dataset_constructor - INFO -   Chunk 229: shape (6, 10000)
# 2025-04-19 13:55:29,558 - dataset_constructor - INFO -   Chunk 230: shape (6, 10000)
# 2025-04-19 13:55:29,558 - dataset_constructor - INFO -   Chunk 231: shape (6, 10000)
# 2025-04-19 13:55:29,559 - dataset_constructor - INFO -   Chunk 232: shape (6, 10000)
# 2025-04-19 13:55:29,559 - dataset_constructor - INFO -   Chunk 233: shape (6, 10000)
# 2025-04-19 13:55:29,559 - dataset_constructor - INFO -   Chunk 234: shape (6, 10000)
# 2025-04-19 13:55:29,560 - dataset_constructor - INFO -   Chunk 235: shape (6, 10000)
# 2025-04-19 13:55:29,560 - dataset_constructor - INFO -   Chunk 236: shape (6, 10000)
# 2025-04-19 13:55:29,561 - dataset_constructor - INFO -   Chunk 237: shape (6, 10000)
# 2025-04-19 13:55:29,561 - dataset_constructor - INFO -   Chunk 238: shape (6, 10000)
# 2025-04-19 13:55:29,562 - dataset_constructor - INFO -   Chunk 239: shape (6, 10000)
# 2025-04-19 13:55:29,562 - dataset_constructor - INFO -   Chunk 240: shape (6, 10000)
# 2025-04-19 13:55:29,563 - dataset_constructor - INFO -   Chunk 241: shape (6, 10000)
# 2025-04-19 13:55:29,563 - dataset_constructor - INFO -   Chunk 242: shape (6, 10000)
# 2025-04-19 13:55:29,564 - dataset_constructor - INFO -   Chunk 243: shape (6, 10000)
# 2025-04-19 13:55:29,564 - dataset_constructor - INFO -   Chunk 244: shape (6, 10000)
# 2025-04-19 13:55:29,565 - dataset_constructor - INFO -   Chunk 245: shape (6, 10000)
# 2025-04-19 13:55:29,565 - dataset_constructor - INFO -   Chunk 246: shape (6, 10000)
# 2025-04-19 13:55:29,566 - dataset_constructor - INFO -   Chunk 247: shape (6, 10000)
# 2025-04-19 13:55:29,566 - dataset_constructor - INFO -   Chunk 248: shape (6, 10000)
# 2025-04-19 13:55:29,567 - dataset_constructor - INFO -   Chunk 249: shape (6, 10000)
# 2025-04-19 13:55:29,567 - dataset_constructor - INFO -   Chunk 250: shape (6, 10000)
# 2025-04-19 13:55:29,568 - dataset_constructor - INFO -   Chunk 251: shape (6, 10000)
# 2025-04-19 13:55:29,568 - dataset_constructor - INFO -   Chunk 252: shape (6, 10000)
# 2025-04-19 13:55:29,568 - dataset_constructor - INFO -   Chunk 253: shape (6, 10000)
# 2025-04-19 13:55:29,569 - dataset_constructor - INFO -   Chunk 254: shape (6, 10000)
# 2025-04-19 13:55:29,570 - dataset_constructor - INFO -   Chunk 255: shape (6, 10000)
# 2025-04-19 13:55:29,570 - dataset_constructor - INFO -   Chunk 256: shape (6, 10000)
# 2025-04-19 13:55:29,570 - dataset_constructor - INFO -   Chunk 257: shape (6, 10000)
# 2025-04-19 13:55:29,571 - dataset_constructor - INFO -   Chunk 258: shape (6, 10000)
# 2025-04-19 13:55:29,571 - dataset_constructor - INFO -   Chunk 259: shape (6, 10000)
# 2025-04-19 13:55:29,572 - dataset_constructor - INFO -   Chunk 260: shape (6, 10000)
# 2025-04-19 13:55:29,572 - dataset_constructor - INFO -   Chunk 261: shape (6, 10000)
# 2025-04-19 13:55:29,573 - dataset_constructor - INFO -   Chunk 262: shape (6, 10000)
# 2025-04-19 13:55:29,573 - dataset_constructor - INFO -   Chunk 263: shape (6, 10000)
# 2025-04-19 13:55:29,574 - dataset_constructor - INFO -   Chunk 264: shape (6, 10000)
# 2025-04-19 13:55:29,574 - dataset_constructor - INFO -   Chunk 265: shape (6, 10000)
# 2025-04-19 13:55:29,574 - dataset_constructor - INFO -   Chunk 266: shape (6, 10000)
# 2025-04-19 13:55:29,575 - dataset_constructor - INFO -   Chunk 267: shape (6, 10000)
# 2025-04-19 13:55:29,575 - dataset_constructor - INFO -   Chunk 268: shape (6, 10000)
# 2025-04-19 13:55:29,576 - dataset_constructor - INFO -   Chunk 269: shape (6, 10000)
# 2025-04-19 13:55:29,577 - dataset_constructor - INFO -   Chunk 270: shape (6, 10000)
# 2025-04-19 13:55:29,577 - dataset_constructor - INFO -   Chunk 271: shape (6, 10000)
# 2025-04-19 13:55:29,577 - dataset_constructor - INFO -   Chunk 272: shape (6, 10000)
# 2025-04-19 13:55:29,578 - dataset_constructor - INFO -   Chunk 273: shape (6, 10000)
# 2025-04-19 13:55:29,578 - dataset_constructor - INFO -   Chunk 274: shape (6, 10000)
# 2025-04-19 13:55:29,579 - dataset_constructor - INFO -   Chunk 275: shape (6, 10000)
# 2025-04-19 13:55:29,579 - dataset_constructor - INFO -   Chunk 276: shape (6, 10000)
# 2025-04-19 13:55:29,580 - dataset_constructor - INFO -   Chunk 277: shape (6, 10000)
# 2025-04-19 13:55:29,580 - dataset_constructor - INFO -   Chunk 278: shape (6, 10000)
# 2025-04-19 13:55:29,581 - dataset_constructor - INFO -   Chunk 279: shape (6, 10000)
# 2025-04-19 13:55:29,581 - dataset_constructor - INFO -   Chunk 280: shape (6, 10000)
# 2025-04-19 13:55:29,581 - dataset_constructor - INFO -   Chunk 281: shape (6, 10000)
# 2025-04-19 13:55:29,582 - dataset_constructor - INFO -   Chunk 282: shape (6, 10000)
# 2025-04-19 13:55:29,583 - dataset_constructor - INFO -   Chunk 283: shape (6, 10000)
# 2025-04-19 13:55:29,583 - dataset_constructor - INFO -   Chunk 284: shape (6, 10000)
# 2025-04-19 13:55:29,584 - dataset_constructor - INFO -   Chunk 285: shape (6, 10000)
# 2025-04-19 13:55:29,584 - dataset_constructor - INFO -   Chunk 286: shape (6, 10000)
# 2025-04-19 13:55:29,585 - dataset_constructor - INFO -   Chunk 287: shape (6, 10000)
# 2025-04-19 13:55:29,585 - dataset_constructor - INFO -   Chunk 288: shape (6, 10000)
# 2025-04-19 13:55:29,586 - dataset_constructor - INFO -   Chunk 289: shape (6, 10000)
# 2025-04-19 13:55:29,586 - dataset_constructor - INFO -   Chunk 290: shape (6, 10000)
# 2025-04-19 13:55:29,587 - dataset_constructor - INFO -   Chunk 291: shape (6, 10000)
# 2025-04-19 13:55:29,587 - dataset_constructor - INFO -   Chunk 292: shape (6, 10000)
# 2025-04-19 13:55:29,587 - dataset_constructor - INFO -   Chunk 293: shape (6, 10000)
# 2025-04-19 13:55:29,588 - dataset_constructor - INFO -   Chunk 294: shape (6, 10000)
# 2025-04-19 13:55:29,589 - dataset_constructor - INFO -   Chunk 295: shape (6, 10000)
# 2025-04-19 13:55:29,589 - dataset_constructor - INFO -   Chunk 296: shape (6, 10000)
# 2025-04-19 13:55:29,590 - dataset_constructor - INFO -   Chunk 297: shape (6, 10000)
# 2025-04-19 13:55:29,590 - dataset_constructor - INFO -   Chunk 298: shape (6, 10000)
# 2025-04-19 13:55:29,590 - dataset_constructor - INFO -   Chunk 299: shape (6, 10000)
# 2025-04-19 13:55:29,591 - dataset_constructor - INFO -   Chunk 300: shape (6, 10000)
# 2025-04-19 13:55:29,591 - dataset_constructor - INFO -   Chunk 301: shape (6, 10000)
# 2025-04-19 13:55:29,592 - dataset_constructor - INFO -   Chunk 302: shape (6, 10000)
# 2025-04-19 13:55:29,592 - dataset_constructor - INFO -   Chunk 303: shape (6, 10000)
# 2025-04-19 13:55:29,593 - dataset_constructor - INFO -   Chunk 304: shape (6, 10000)
# 2025-04-19 13:55:29,593 - dataset_constructor - INFO -   Chunk 305: shape (6, 10000)
# 2025-04-19 13:55:29,594 - dataset_constructor - INFO -   Chunk 306: shape (6, 10000)
# 2025-04-19 13:55:29,594 - dataset_constructor - INFO -   Chunk 307: shape (6, 10000)
# 2025-04-19 13:55:29,595 - dataset_constructor - INFO -   Chunk 308: shape (6, 10000)
# 2025-04-19 13:55:29,595 - dataset_constructor - INFO -   Chunk 309: shape (6, 10000)
# 2025-04-19 13:55:29,596 - dataset_constructor - INFO -   Chunk 310: shape (6, 10000)
# 2025-04-19 13:55:29,596 - dataset_constructor - INFO -   Chunk 311: shape (6, 10000)
# 2025-04-19 13:55:29,597 - dataset_constructor - INFO -   Chunk 312: shape (6, 10000)
# 2025-04-19 13:55:29,597 - dataset_constructor - INFO -   Chunk 313: shape (6, 10000)
# 2025-04-19 13:55:29,598 - dataset_constructor - INFO -   Chunk 314: shape (6, 10000)
# 2025-04-19 13:55:29,598 - dataset_constructor - INFO -   Chunk 315: shape (6, 10000)
# 2025-04-19 13:55:29,599 - dataset_constructor - INFO -   Chunk 316: shape (6, 10000)
# 2025-04-19 13:55:29,599 - dataset_constructor - INFO -   Chunk 317: shape (6, 10000)
# 2025-04-19 13:55:29,599 - dataset_constructor - INFO -   Chunk 318: shape (6, 10000)
# 2025-04-19 13:55:29,600 - dataset_constructor - INFO -   Chunk 319: shape (6, 10000)
# 2025-04-19 13:55:29,601 - dataset_constructor - INFO -   Chunk 320: shape (6, 10000)
# 2025-04-19 13:55:29,601 - dataset_constructor - INFO -   Chunk 321: shape (6, 10000)
# 2025-04-19 13:55:29,602 - dataset_constructor - INFO -   Chunk 322: shape (6, 10000)
# 2025-04-19 13:55:29,602 - dataset_constructor - INFO -   Chunk 323: shape (6, 10000)
# 2025-04-19 13:55:29,602 - dataset_constructor - INFO -   Chunk 324: shape (6, 10000)
# 2025-04-19 13:55:29,603 - dataset_constructor - INFO -   Chunk 325: shape (6, 10000)
# 2025-04-19 13:55:29,603 - dataset_constructor - INFO -   Chunk 326: shape (6, 10000)
# 2025-04-19 13:55:29,604 - dataset_constructor - INFO -   Chunk 327: shape (6, 10000)
# 2025-04-19 13:55:29,604 - dataset_constructor - INFO -   Chunk 328: shape (6, 10000)
# 2025-04-19 13:55:29,605 - dataset_constructor - INFO -   Chunk 329: shape (6, 10000)
# 2025-04-19 13:55:29,605 - dataset_constructor - INFO -   Chunk 330: shape (6, 10000)
# 2025-04-19 13:55:29,606 - dataset_constructor - INFO -   Chunk 331: shape (6, 10000)
# 2025-04-19 13:55:29,606 - dataset_constructor - INFO -   Chunk 332: shape (6, 10000)
# 2025-04-19 13:55:29,607 - dataset_constructor - INFO -   Chunk 333: shape (6, 10000)
# 2025-04-19 13:55:29,607 - dataset_constructor - INFO -   Chunk 334: shape (6, 10000)
# 2025-04-19 13:55:29,608 - dataset_constructor - INFO -   Chunk 335: shape (6, 10000)
# 2025-04-19 13:55:29,608 - dataset_constructor - INFO -   Chunk 336: shape (6, 10000)
# 2025-04-19 13:55:29,609 - dataset_constructor - INFO -   Chunk 337: shape (6, 10000)
# 2025-04-19 13:55:29,609 - dataset_constructor - INFO -   Chunk 338: shape (6, 10000)
# 2025-04-19 13:55:29,610 - dataset_constructor - INFO -   Chunk 339: shape (6, 10000)
# 2025-04-19 13:55:29,610 - dataset_constructor - INFO -   Chunk 340: shape (6, 10000)
# 2025-04-19 13:55:29,611 - dataset_constructor - INFO -   Chunk 341: shape (6, 10000)
# 2025-04-19 13:55:29,611 - dataset_constructor - INFO -   Chunk 342: shape (6, 10000)
# 2025-04-19 13:55:29,611 - dataset_constructor - INFO -   Chunk 343: shape (6, 10000)
# 2025-04-19 13:55:29,612 - dataset_constructor - INFO -   Chunk 344: shape (6, 10000)
# 2025-04-19 13:55:29,613 - dataset_constructor - INFO -   Chunk 345: shape (6, 10000)
# 2025-04-19 13:55:29,613 - dataset_constructor - INFO -   Chunk 346: shape (6, 10000)
# 2025-04-19 13:55:29,614 - dataset_constructor - INFO -   Chunk 347: shape (6, 10000)
# 2025-04-19 13:55:29,614 - dataset_constructor - INFO -   Chunk 348: shape (6, 10000)
# 2025-04-19 13:55:29,614 - dataset_constructor - INFO -   Chunk 349: shape (6, 10000)
# 2025-04-19 13:55:29,615 - dataset_constructor - INFO -   Chunk 350: shape (6, 10000)
# 2025-04-19 13:55:29,615 - dataset_constructor - INFO -   Chunk 351: shape (6, 10000)
# 2025-04-19 13:55:29,616 - dataset_constructor - INFO -   Chunk 352: shape (6, 10000)
# 2025-04-19 13:55:29,616 - dataset_constructor - INFO -   Chunk 353: shape (6, 10000)
# 2025-04-19 13:55:29,617 - dataset_constructor - INFO -   Chunk 354: shape (6, 10000)
# 2025-04-19 13:55:29,617 - dataset_constructor - INFO -   Chunk 355: shape (6, 10000)
# 2025-04-19 13:55:29,618 - dataset_constructor - INFO -   Chunk 356: shape (6, 10000)
# 2025-04-19 13:55:29,618 - dataset_constructor - INFO -   Chunk 357: shape (6, 10000)
# 2025-04-19 13:55:29,619 - dataset_constructor - INFO -   Chunk 358: shape (6, 10000)
# 2025-04-19 13:55:29,619 - dataset_constructor - INFO -   Chunk 359: shape (6, 10000)
# 2025-04-19 13:55:29,620 - dataset_constructor - INFO -   Chunk 360: shape (6, 10000)
# 2025-04-19 13:55:29,620 - dataset_constructor - INFO -   Chunk 361: shape (6, 10000)
# 2025-04-19 13:55:29,621 - dataset_constructor - INFO -   Chunk 362: shape (6, 10000)
# 2025-04-19 13:55:29,621 - dataset_constructor - INFO -   Chunk 363: shape (6, 10000)
# 2025-04-19 13:55:29,622 - dataset_constructor - INFO -   Chunk 364: shape (6, 10000)
# 2025-04-19 13:55:29,622 - dataset_constructor - INFO -   Chunk 365: shape (6, 10000)
# 2025-04-19 13:55:29,623 - dataset_constructor - INFO -   Chunk 366: shape (6, 10000)
# 2025-04-19 13:55:29,623 - dataset_constructor - INFO -   Chunk 367: shape (6, 10000)
# 2025-04-19 13:55:29,624 - dataset_constructor - INFO -   Chunk 368: shape (6, 10000)
# 2025-04-19 13:55:29,624 - dataset_constructor - INFO -   Chunk 369: shape (6, 10000)
# 2025-04-19 13:55:29,625 - dataset_constructor - INFO -   Chunk 370: shape (6, 10000)
# 2025-04-19 13:55:29,625 - dataset_constructor - INFO -   Chunk 371: shape (6, 10000)
# 2025-04-19 13:55:29,626 - dataset_constructor - INFO -   Chunk 372: shape (6, 10000)
# 2025-04-19 13:55:29,626 - dataset_constructor - INFO -   Chunk 373: shape (6, 10000)
# 2025-04-19 13:55:29,627 - dataset_constructor - INFO -   Chunk 374: shape (6, 10000)
# 2025-04-19 13:55:29,627 - dataset_constructor - INFO -   Chunk 375: shape (6, 10000)
# 2025-04-19 13:55:29,628 - dataset_constructor - INFO -   Chunk 376: shape (6, 10000)
# 2025-04-19 13:55:29,628 - dataset_constructor - INFO -   Chunk 377: shape (6, 10000)
# 2025-04-19 13:55:29,628 - dataset_constructor - INFO -   Chunk 378: shape (6, 10000)
# 2025-04-19 13:55:29,629 - dataset_constructor - INFO -   Chunk 379: shape (6, 10000)
# 2025-04-19 13:55:29,629 - dataset_constructor - INFO -   Chunk 380: shape (6, 10000)
# 2025-04-19 13:55:29,630 - dataset_constructor - INFO -   Chunk 381: shape (6, 10000)
# 2025-04-19 13:55:29,631 - dataset_constructor - INFO -   Chunk 382: shape (6, 10000)
# 2025-04-19 13:55:29,631 - dataset_constructor - INFO -   Chunk 383: shape (6, 10000)
# 2025-04-19 13:55:29,632 - dataset_constructor - INFO -   Chunk 384: shape (6, 10000)
# 2025-04-19 13:55:29,632 - dataset_constructor - INFO -   Chunk 385: shape (6, 10000)
# 2025-04-19 13:55:29,632 - dataset_constructor - INFO -   Chunk 386: shape (6, 10000)
# 2025-04-19 13:55:29,633 - dataset_constructor - INFO -   Chunk 387: shape (6, 10000)
# 2025-04-19 13:55:29,633 - dataset_constructor - INFO -   Chunk 388: shape (6, 10000)
# 2025-04-19 13:55:29,634 - dataset_constructor - INFO -   Chunk 389: shape (6, 10000)
# 2025-04-19 13:55:29,634 - dataset_constructor - INFO -   Chunk 390: shape (6, 10000)
# 2025-04-19 13:55:29,635 - dataset_constructor - INFO -   Chunk 391: shape (6, 10000)
# 2025-04-19 13:55:29,635 - dataset_constructor - INFO -   Chunk 392: shape (6, 10000)
# 2025-04-19 13:55:29,636 - dataset_constructor - INFO -   Chunk 393: shape (6, 10000)
# 2025-04-19 13:55:29,636 - dataset_constructor - INFO -   Chunk 394: shape (6, 10000)
# 2025-04-19 13:55:29,637 - dataset_constructor - INFO -   Chunk 395: shape (6, 10000)
# 2025-04-19 13:55:29,637 - dataset_constructor - INFO -   Chunk 396: shape (6, 10000)
# 2025-04-19 13:55:29,638 - dataset_constructor - INFO -   Chunk 397: shape (6, 10000)
# 2025-04-19 13:55:29,638 - dataset_constructor - INFO -   Chunk 398: shape (6, 10000)
# 2025-04-19 13:55:29,639 - dataset_constructor - INFO -   Chunk 399: shape (6, 10000)
# 2025-04-19 13:55:29,639 - dataset_constructor - INFO -   Chunk 400: shape (6, 10000)
# 2025-04-19 13:55:29,640 - dataset_constructor - INFO -   Chunk 401: shape (6, 10000)
# 2025-04-19 13:55:29,640 - dataset_constructor - INFO -   Chunk 402: shape (6, 10000)
# 2025-04-19 13:55:29,641 - dataset_constructor - INFO -   Chunk 403: shape (6, 10000)
# 2025-04-19 13:55:29,641 - dataset_constructor - INFO -   Chunk 404: shape (6, 10000)
# 2025-04-19 13:55:29,642 - dataset_constructor - INFO -   Chunk 405: shape (6, 10000)
# 2025-04-19 13:55:29,642 - dataset_constructor - INFO -   Chunk 406: shape (6, 10000)
# 2025-04-19 13:55:29,643 - dataset_constructor - INFO -   Chunk 407: shape (6, 10000)
# 2025-04-19 13:55:29,643 - dataset_constructor - INFO -   Chunk 408: shape (6, 10000)
# 2025-04-19 13:55:29,644 - dataset_constructor - INFO -   Chunk 409: shape (6, 10000)
# 2025-04-19 13:55:29,644 - dataset_constructor - INFO -   Chunk 410: shape (6, 10000)
# 2025-04-19 13:55:29,645 - dataset_constructor - INFO -   Chunk 411: shape (6, 10000)
# 2025-04-19 13:55:29,645 - dataset_constructor - INFO -   Chunk 412: shape (6, 10000)
# 2025-04-19 13:55:29,646 - dataset_constructor - INFO -   Chunk 413: shape (6, 10000)
# 2025-04-19 13:55:29,646 - dataset_constructor - INFO -   Chunk 414: shape (6, 10000)
# 2025-04-19 13:55:29,647 - dataset_constructor - INFO -   Chunk 415: shape (6, 10000)
# 2025-04-19 13:55:29,647 - dataset_constructor - INFO -   Chunk 416: shape (6, 10000)
# 2025-04-19 13:55:29,648 - dataset_constructor - INFO -   Chunk 417: shape (6, 10000)
# 2025-04-19 13:55:29,648 - dataset_constructor - INFO -   Chunk 418: shape (6, 10000)
# 2025-04-19 13:55:29,649 - dataset_constructor - INFO -   Chunk 419: shape (6, 10000)
# 2025-04-19 13:55:29,649 - dataset_constructor - INFO -   Chunk 420: shape (6, 10000)
# 2025-04-19 13:55:29,650 - dataset_constructor - INFO -   Chunk 421: shape (6, 10000)
# 2025-04-19 13:55:29,650 - dataset_constructor - INFO -   Chunk 422: shape (6, 10000)
# 2025-04-19 13:55:29,651 - dataset_constructor - INFO -   Chunk 423: shape (6, 10000)
# 2025-04-19 13:55:29,651 - dataset_constructor - INFO -   Chunk 424: shape (6, 10000)
# 2025-04-19 13:55:29,652 - dataset_constructor - INFO -   Chunk 425: shape (6, 10000)
# 2025-04-19 13:55:29,652 - dataset_constructor - INFO -   Chunk 426: shape (6, 10000)
# 2025-04-19 13:55:29,653 - dataset_constructor - INFO -   Chunk 427: shape (6, 10000)
# 2025-04-19 13:55:29,653 - dataset_constructor - INFO -   Chunk 428: shape (6, 10000)
# 2025-04-19 13:55:29,654 - dataset_constructor - INFO -   Chunk 429: shape (6, 10000)
# 2025-04-19 13:55:29,654 - dataset_constructor - INFO -   Chunk 430: shape (6, 10000)
# 2025-04-19 13:55:29,654 - dataset_constructor - INFO -   Chunk 431: shape (6, 10000)
# 2025-04-19 13:55:29,655 - dataset_constructor - INFO -   Chunk 432: shape (6, 10000)
# 2025-04-19 13:55:29,655 - dataset_constructor - INFO -   Chunk 433: shape (6, 10000)
# 2025-04-19 13:55:29,656 - dataset_constructor - INFO -   Chunk 434: shape (6, 10000)
# 2025-04-19 13:55:29,657 - dataset_constructor - INFO -   Chunk 435: shape (6, 10000)
# 2025-04-19 13:55:29,657 - dataset_constructor - INFO -   Chunk 436: shape (6, 10000)
# 2025-04-19 13:55:29,658 - dataset_constructor - INFO -   Chunk 437: shape (6, 10000)
# 2025-04-19 13:55:29,658 - dataset_constructor - INFO -   Chunk 438: shape (6, 10000)
# 2025-04-19 13:55:29,658 - dataset_constructor - INFO -   Chunk 439: shape (6, 10000)
# 2025-04-19 13:55:29,659 - dataset_constructor - INFO -   Chunk 440: shape (6, 10000)
# 2025-04-19 13:55:29,660 - dataset_constructor - INFO -   Chunk 441: shape (6, 10000)
# 2025-04-19 13:55:29,660 - dataset_constructor - INFO -   Chunk 442: shape (6, 10000)
# 2025-04-19 13:55:29,661 - dataset_constructor - INFO -   Chunk 443: shape (6, 10000)
# 2025-04-19 13:55:29,661 - dataset_constructor - INFO -   Chunk 444: shape (6, 10000)
# 2025-04-19 13:55:29,661 - dataset_constructor - INFO -   Chunk 445: shape (6, 10000)
# 2025-04-19 13:55:29,662 - dataset_constructor - INFO -   Chunk 446: shape (6, 10000)
# 2025-04-19 13:55:29,663 - dataset_constructor - INFO -   Chunk 447: shape (6, 10000)
# 2025-04-19 13:55:29,663 - dataset_constructor - INFO -   Chunk 448: shape (6, 10000)
# 2025-04-19 13:55:29,664 - dataset_constructor - INFO -   Chunk 449: shape (6, 10000)
# 2025-04-19 13:55:29,664 - dataset_constructor - INFO -   Chunk 450: shape (6, 10000)
# 2025-04-19 13:55:29,664 - dataset_constructor - INFO -   Chunk 451: shape (6, 10000)
# 2025-04-19 13:55:29,665 - dataset_constructor - INFO -   Chunk 452: shape (6, 10000)
# 2025-04-19 13:55:29,666 - dataset_constructor - INFO -   Chunk 453: shape (6, 10000)
# 2025-04-19 13:55:29,666 - dataset_constructor - INFO -   Chunk 454: shape (6, 10000)
# 2025-04-19 13:55:29,666 - dataset_constructor - INFO -   Chunk 455: shape (6, 10000)
# 2025-04-19 13:55:29,667 - dataset_constructor - INFO -   Chunk 456: shape (6, 10000)
# 2025-04-19 13:55:29,667 - dataset_constructor - INFO -   Chunk 457: shape (6, 10000)
# 2025-04-19 13:55:29,668 - dataset_constructor - INFO -   Chunk 458: shape (6, 10000)
# 2025-04-19 13:55:29,669 - dataset_constructor - INFO -   Chunk 459: shape (6, 10000)
# 2025-04-19 13:55:29,669 - dataset_constructor - INFO -   Chunk 460: shape (6, 10000)
# 2025-04-19 13:55:29,669 - dataset_constructor - INFO -   Chunk 461: shape (6, 10000)
# 2025-04-19 13:55:29,670 - dataset_constructor - INFO -   Chunk 462: shape (6, 10000)
# 2025-04-19 13:55:29,670 - dataset_constructor - INFO -   Chunk 463: shape (6, 10000)
# 2025-04-19 13:55:29,671 - dataset_constructor - INFO -   Chunk 464: shape (6, 10000)
# 2025-04-19 13:55:29,672 - dataset_constructor - INFO -   Chunk 465: shape (6, 10000)
# 2025-04-19 13:55:29,672 - dataset_constructor - INFO -   Chunk 466: shape (6, 10000)
# 2025-04-19 13:55:29,672 - dataset_constructor - INFO -   Chunk 467: shape (6, 10000)
# 2025-04-19 13:55:29,673 - dataset_constructor - INFO -   Chunk 468: shape (6, 10000)
# 2025-04-19 13:55:29,674 - dataset_constructor - INFO -   Chunk 469: shape (6, 10000)
# 2025-04-19 13:55:29,674 - dataset_constructor - INFO -   Chunk 470: shape (6, 10000)
# 2025-04-19 13:55:29,675 - dataset_constructor - INFO -   Chunk 471: shape (6, 10000)
# 2025-04-19 13:55:29,675 - dataset_constructor - INFO -   Chunk 472: shape (6, 10000)
# 2025-04-19 13:55:29,676 - dataset_constructor - INFO -   Chunk 473: shape (6, 10000)
# 2025-04-19 13:55:29,676 - dataset_constructor - INFO -   Chunk 474: shape (6, 10000)
# 2025-04-19 13:55:29,676 - dataset_constructor - INFO -   Chunk 475: shape (6, 10000)
# 2025-04-19 13:55:29,677 - dataset_constructor - INFO -   Chunk 476: shape (6, 10000)
# 2025-04-19 13:55:29,677 - dataset_constructor - INFO -   Chunk 477: shape (6, 10000)
# 2025-04-19 13:55:29,678 - dataset_constructor - INFO -   Chunk 478: shape (6, 10000)
# 2025-04-19 13:55:29,678 - dataset_constructor - INFO -   Chunk 479: shape (6, 10000)
# 2025-04-19 13:55:29,679 - dataset_constructor - INFO -   Chunk 480: shape (6, 10000)
# 2025-04-19 13:55:29,680 - dataset_constructor - INFO -   Chunk 481: shape (6, 10000)
# 2025-04-19 13:55:29,680 - dataset_constructor - INFO -   Chunk 482: shape (6, 10000)
# 2025-04-19 13:55:29,680 - dataset_constructor - INFO -   Chunk 483: shape (6, 10000)
# 2025-04-19 13:55:29,681 - dataset_constructor - INFO -   Chunk 484: shape (6, 10000)
# 2025-04-19 13:55:29,681 - dataset_constructor - INFO -   Chunk 485: shape (6, 10000)
# 2025-04-19 13:55:29,682 - dataset_constructor - INFO -   Chunk 486: shape (6, 10000)
# 2025-04-19 13:55:29,682 - dataset_constructor - INFO -   Chunk 487: shape (6, 10000)
# 2025-04-19 13:55:29,683 - dataset_constructor - INFO -   Chunk 488: shape (6, 10000)
# 2025-04-19 13:55:29,683 - dataset_constructor - INFO -   Chunk 489: shape (6, 10000)
# 2025-04-19 13:55:29,683 - dataset_constructor - INFO -   Chunk 490: shape (6, 10000)
# 2025-04-19 13:55:29,684 - dataset_constructor - INFO -   Chunk 491: shape (6, 10000)
# 2025-04-19 13:55:29,685 - dataset_constructor - INFO -   Chunk 492: shape (6, 10000)
# 2025-04-19 13:55:29,685 - dataset_constructor - INFO -   Chunk 493: shape (6, 10000)
# 2025-04-19 13:55:29,686 - dataset_constructor - INFO -   Chunk 494: shape (6, 10000)
# 2025-04-19 13:55:29,686 - dataset_constructor - INFO -   Chunk 495: shape (6, 10000)
# 2025-04-19 13:55:29,687 - dataset_constructor - INFO -   Chunk 496: shape (6, 10000)
# 2025-04-19 13:55:29,687 - dataset_constructor - INFO -   Chunk 497: shape (6, 10000)
# 2025-04-19 13:55:29,688 - dataset_constructor - INFO -   Chunk 498: shape (6, 10000)
# 2025-04-19 13:55:29,688 - dataset_constructor - INFO -   Chunk 499: shape (6, 10000)
# 2025-04-19 13:55:29,689 - dataset_constructor - INFO -   Chunk 500: shape (6, 10000)
# 2025-04-19 13:55:29,689 - dataset_constructor - INFO -   Chunk 501: shape (6, 10000)
# 2025-04-19 13:55:29,690 - dataset_constructor - INFO -   Chunk 502: shape (6, 10000)
# 2025-04-19 13:55:29,690 - dataset_constructor - INFO -   Chunk 503: shape (6, 10000)
# 2025-04-19 13:55:29,690 - dataset_constructor - INFO -   Chunk 504: shape (6, 10000)
# 2025-04-19 13:55:29,691 - dataset_constructor - INFO -   Chunk 505: shape (6, 10000)
# 2025-04-19 13:55:29,692 - dataset_constructor - INFO -   Chunk 506: shape (6, 10000)
# 2025-04-19 13:55:29,692 - dataset_constructor - INFO -   Chunk 507: shape (6, 10000)
# 2025-04-19 13:55:29,693 - dataset_constructor - INFO -   Chunk 508: shape (6, 10000)
# 2025-04-19 13:55:29,693 - dataset_constructor - INFO -   Chunk 509: shape (6, 10000)
# 2025-04-19 13:55:29,694 - dataset_constructor - INFO -   Chunk 510: shape (6, 10000)
# 2025-04-19 13:55:29,694 - dataset_constructor - INFO -   Chunk 511: shape (6, 10000)
# 2025-04-19 13:55:29,695 - dataset_constructor - INFO -   Chunk 512: shape (6, 10000)
# 2025-04-19 13:55:29,695 - dataset_constructor - INFO -   Chunk 513: shape (6, 10000)
# 2025-04-19 13:55:29,696 - dataset_constructor - INFO -   Chunk 514: shape (6, 10000)
# 2025-04-19 13:55:29,696 - dataset_constructor - INFO -   Chunk 515: shape (6, 10000)
# 2025-04-19 13:55:29,697 - dataset_constructor - INFO -   Chunk 516: shape (6, 10000)
# 2025-04-19 13:55:29,697 - dataset_constructor - INFO -   Chunk 517: shape (6, 10000)
# 2025-04-19 13:55:29,698 - dataset_constructor - INFO -   Chunk 518: shape (6, 10000)
# 2025-04-19 13:55:29,698 - dataset_constructor - INFO -   Chunk 519: shape (6, 10000)
# 2025-04-19 13:55:29,699 - dataset_constructor - INFO -   Chunk 520: shape (6, 10000)
# 2025-04-19 13:55:29,699 - dataset_constructor - INFO -   Chunk 521: shape (6, 10000)
# 2025-04-19 13:55:29,700 - dataset_constructor - INFO -   Chunk 522: shape (6, 10000)
# 2025-04-19 13:55:29,700 - dataset_constructor - INFO -   Chunk 523: shape (6, 10000)
# 2025-04-19 13:55:29,701 - dataset_constructor - INFO -   Chunk 524: shape (6, 10000)
# 2025-04-19 13:55:29,701 - dataset_constructor - INFO -   Chunk 525: shape (6, 10000)
# 2025-04-19 13:55:29,702 - dataset_constructor - INFO -   Chunk 526: shape (6, 10000)
# 2025-04-19 13:55:29,702 - dataset_constructor - INFO -   Chunk 527: shape (6, 10000)
# 2025-04-19 13:55:29,703 - dataset_constructor - INFO -   Chunk 528: shape (6, 10000)
# 2025-04-19 13:55:29,703 - dataset_constructor - INFO -   Chunk 529: shape (6, 10000)
# 2025-04-19 13:55:29,704 - dataset_constructor - INFO -   Chunk 530: shape (6, 10000)
# 2025-04-19 13:55:29,704 - dataset_constructor - INFO -   Chunk 531: shape (6, 10000)
# 2025-04-19 13:55:29,704 - dataset_constructor - INFO -   Chunk 532: shape (6, 10000)
# 2025-04-19 13:55:29,705 - dataset_constructor - INFO -   Chunk 533: shape (6, 10000)
# 2025-04-19 13:55:29,705 - dataset_constructor - INFO -   Chunk 534: shape (6, 10000)
# 2025-04-19 13:55:29,706 - dataset_constructor - INFO -   Chunk 535: shape (6, 10000)
# 2025-04-19 13:55:29,706 - dataset_constructor - INFO -   Chunk 536: shape (6, 10000)
# 2025-04-19 13:55:29,707 - dataset_constructor - INFO -   Chunk 537: shape (6, 10000)
# 2025-04-19 13:55:29,708 - dataset_constructor - INFO -   Chunk 538: shape (6, 10000)
# 2025-04-19 13:55:29,708 - dataset_constructor - INFO -   Chunk 539: shape (6, 10000)
# 2025-04-19 13:55:29,709 - dataset_constructor - INFO -   Chunk 540: shape (6, 10000)
# 2025-04-19 13:55:29,709 - dataset_constructor - INFO -   Chunk 541: shape (6, 10000)
# 2025-04-19 13:55:29,710 - dataset_constructor - INFO -   Chunk 542: shape (6, 10000)
# 2025-04-19 13:55:29,710 - dataset_constructor - INFO -   Chunk 543: shape (6, 10000)
# 2025-04-19 13:55:29,710 - dataset_constructor - INFO -   Chunk 544: shape (6, 10000)
# 2025-04-19 13:55:29,711 - dataset_constructor - INFO -   Chunk 545: shape (6, 10000)
# 2025-04-19 13:55:29,712 - dataset_constructor - INFO -   Chunk 546: shape (6, 10000)
# 2025-04-19 13:55:29,712 - dataset_constructor - INFO -   Chunk 547: shape (6, 10000)
# 2025-04-19 13:55:29,713 - dataset_constructor - INFO -   Chunk 548: shape (6, 10000)
# 2025-04-19 13:55:29,713 - dataset_constructor - INFO -   Chunk 549: shape (6, 10000)
# 2025-04-19 13:55:29,713 - dataset_constructor - INFO -   Chunk 550: shape (6, 10000)
# 2025-04-19 13:55:29,714 - dataset_constructor - INFO -   Chunk 551: shape (6, 10000)
# 2025-04-19 13:55:29,715 - dataset_constructor - INFO -   Chunk 552: shape (6, 10000)
# 2025-04-19 13:55:29,715 - dataset_constructor - INFO -   Chunk 553: shape (6, 10000)
# 2025-04-19 13:55:29,716 - dataset_constructor - INFO -   Chunk 554: shape (6, 10000)
# 2025-04-19 13:55:29,716 - dataset_constructor - INFO -   Chunk 555: shape (6, 10000)
# 2025-04-19 13:55:29,716 - dataset_constructor - INFO -   Chunk 556: shape (6, 10000)
# 2025-04-19 13:55:29,717 - dataset_constructor - INFO -   Chunk 557: shape (6, 10000)
# 2025-04-19 13:55:29,717 - dataset_constructor - INFO -   Chunk 558: shape (6, 10000)
# 2025-04-19 13:55:29,718 - dataset_constructor - INFO -   Chunk 559: shape (6, 10000)
# 2025-04-19 13:55:29,719 - dataset_constructor - INFO -   Chunk 560: shape (6, 10000)
# 2025-04-19 13:55:29,719 - dataset_constructor - INFO -   Chunk 561: shape (6, 10000)
# 2025-04-19 13:55:29,719 - dataset_constructor - INFO -   Chunk 562: shape (6, 10000)
# ...
# 2025-04-19 13:55:31,594 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Umpush-LightOblique.ttf', name='Umpush', style='oblique', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2025-04-19 13:55:31,595 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-Bold.otf', name='C059', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,595 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypewriter-Bold.ttf', name='Tlwg Typewriter', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,596 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-BoldItalic.otf', name='Nimbus Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-04-19 13:55:31,596 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Meera-Regular.ttf', name='Meera', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,597 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda.ttf', name='Garuda', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,598 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypewriter-BoldOblique.ttf', name='Tlwg Typewriter', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-04-19 13:55:31,598 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Bold.ttf', name='Liberation Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,599 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-Bold.ttf', name='Kinnari', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,599 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Thin.otf', name='Gayathri', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,600 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSans.ttf', name='FreeSans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,600 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist-Oblique.ttf', name='Tlwg Typist', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-04-19 13:55:31,602 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/openoffice/opens___.ttf', name='OpenSymbol', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,603 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Italic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-04-19 13:55:31,603 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,604 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-BoldItalic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-04-19 13:55:31,605 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-bengali/Lohit-Bengali.ttf', name='Lohit Bengali', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,605 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-B.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,606 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-RI.ttf', name='Ubuntu Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-04-19 13:55:31,607 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Laksaman.ttf', name='Laksaman', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,607 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansBoldOblique.ttf', name='FreeSans', style='oblique', variant='normal', weight=600, stretch='normal', size='scalable')) = 11.24
# 2025-04-19 13:55:31,608 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-MI.ttf', name='Ubuntu', style='italic', variant='normal', weight=500, stretch='normal', size='scalable')) = 11.145
# 2025-04-19 13:55:31,609 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-telugu/Lohit-Telugu.ttf', name='Lohit Telugu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,610 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Manjari-Thin.otf', name='Manjari', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,610 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Medium.ttf', name='Yrsa', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2025-04-19 13:55:31,611 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-BoldItalic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-04-19 13:55:31,611 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst-one/KacstOne-Bold.ttf', name='KacstOne', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-04-19 13:55:31,612 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgMono-BoldOblique.ttf', name='Tlwg Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-04-19 13:55:31,613 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Laksaman-Italic.ttf', name='Laksaman', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-04-19 13:55:31,613 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,614 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusRoman-BoldItalic.otf', name='Nimbus Roman', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-04-19 13:55:31,615 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Uroob-Regular.ttf', name='Uroob', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,616 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,616 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstLetter.ttf', name='KacstLetter', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2025-04-19 13:55:31,617 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Sawasdee.ttf', name='Sawasdee', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,618 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstQurn.ttf', name='KacstQurn', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,618 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,619 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst-one/KacstOne.ttf', name='KacstOne', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,620 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist.ttf', name='Tlwg Typist', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,620 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMono.ttf', name='FreeMono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,621 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/samanata.ttf', name='Samanata', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,621 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Sarai/Sarai.ttf', name='Sarai', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,623 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Italic.otf', name='Nimbus Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-04-19 13:55:31,623 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2025-04-19 13:55:31,624 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Oblique.otf', name='Nimbus Sans Narrow', style='oblique', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2025-04-19 13:55:31,625 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2025-04-19 13:55:31,625 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/mitra.ttf', name='Mitra Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-04-19 13:55:31,626 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=14.399999999999999 to DejaVu Sans ('/home/honglab/leijiaxin/anaconda3/envs/MARBLE/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# 2025-04-19 13:55:32,546 - matplotlib.colorbar - DEBUG - colorbar update normal <matplotlib.colors.Normalize object at 0x7fc9e66cdd30> <matplotlib.colors.Normalize object at 0x7fc9e66cdd30>
# 2025-04-19 13:55:32,547 - matplotlib.colorbar - DEBUG - colorbar update normal <matplotlib.colors.Normalize object at 0x7fc9e66cdd30> <matplotlib.colors.Normalize object at 0x7fc9e66cdd30>
# 2025-04-19 13:55:32,551 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fc9e6566250>
# 2025-04-19 13:55:32,555 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fc9e6566250>
# 2025-04-19 13:55:32,559 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fc9e655cfd0>
# 2025-04-19 13:55:36,370 - dataset_constructor - INFO - Loaded bandpower dataset from /home/honglab/leijiaxin/MARBLE/datasets/20250419_130924_bandpower_dataset.npz with 3267 chunks and bands: ['gamma', 'high_gamma']
# Bandpower Dataset:
# Number of chunks: 3267
# Dataset attributes: ['band_definitions', 'bands', 'config', 'day_night_labels', 'event_labels', 'file_indices', 'metadata', 'night_end_hour', 'night_start_hour', 'time_arrays']
# Available bands: ['gamma', 'high_gamma']
# Band gamma - Number of batches: 5
# Band data shape for gamma: (19995, 6)
# Visualizing 6 channels for gamma band
# Successfully visualized gamma band data
# Band high_gamma - Number of batches: 5
# Band data shape for high_gamma: (19995, 6)
# Visualizing 6 channels for high_gamma band
# Successfully visualized high_gamma band data
# 2025-04-19 13:55:56,406 - dataset_constructor - INFO - Loaded event segment dataset shapes:
# 2025-04-19 13:55:56,438 - dataset_constructor - INFO -   Shape distribution: {(6, 100): 160613}
# 2025-04-19 13:55:56,439 - dataset_constructor - INFO - Loaded event segment dataset from /home/honglab/leijiaxin/MARBLE/datasets/20250419_130924_event_segments_dataset.npz with 160613 segments
# Event Segment Dataset:
# Number of segments: 160613
# Dataset attributes: ['config', 'data', 'day_night_labels', 'event_labels', 'event_sources', 'high_band', 'low_band', 'metadata', 'night_end_hour', 'night_start_hour', 'post_event_ms', 'pre_event_ms', 'rel_time_arrays', 'segment_params', 'time_arrays']
# Metadata keys: ['creation_date', 'config', 'dataset_type', 'pre_event_ms', 'post_event_ms', 'event_detection', 'day_night_params', 'used_files', 'segment_info']
# Event detection bands: Low=[80, 250], High=[250, 400]
# Number of segments in metadata: 160613
# Event type counts from metadata: {1: 0, 2: 0, 3: 0}
# Event dataset - Number of batches: 5
# Batch item shape: (6, 500)
# Time array shape: (500,)
# Events array shape: (500,)
#
# Segment 1 shape: (500,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 434
#     431     event_indices = np.where(segment_events > 0)[0]
#     432     if len(event_indices) > 0:
#     433         # Get the event type from the first non-zero index
# --> 434         event_type = int(segment_events[event_indices[0]])
#     435         print(f"Event type: {event_type}")
#     437 # If no event type found in labels, try getting from segment info
#
# TypeError: 'float' object is not subscriptable

# %%
batch_data,band_time,band_events = bp_dataset.get_batched_data(num_chunks=50000, batch_size=500, chunks_per_batch_item=100)
# Out:
# 2025-04-19 14:07:18,691 - dataset_constructor - INFO - Using band 'gamma' for data

# %%
# Find non-zero elements in band_events (which is a list of arrays)
nonzero_events = []
for event_array in band_events:
    # Get indices where event values are non-zero
    nonzero_indices = np.where(event_array > 0)[0]
    if len(nonzero_indices) > 0:
        nonzero_events.append((event_array, nonzero_indices))

print(f"Found {len(nonzero_events)} segments with non-zero events")
if nonzero_events:
    # Display the first few non-zero events
    for i, (event_array, indices) in enumerate(nonzero_events[:3]):
        print(f"Segment {i}: Non-zero indices {indices}, values {event_array[indices]}")
# Out:
# Found 32 segments with non-zero events
# Segment 0: Non-zero indices [   180    181    182 ... 398371 398372 398373], values [1. 1. 1. ... 1. 1. 1.]
# Segment 1: Non-zero indices [     3      4      5 ... 399842 399843 399844], values [1. 1. 1. ... 1. 1. 1.]
# Segment 2: Non-zero indices [   108    109    110 ... 399895 399896 399897], values [1. 1. 1. ... 1. 1. 1.]

# %%
batch_data[10].shape
# Out:
# (399900, 6)

# %%
band_time
# Out:
# [array([21600.05, 21600.1 , 21600.15, ..., 57999.85, 57999.9 , 57999.95]),
#  array([58000.05, 58000.1 , 58000.15, ..., 78999.85, 78999.9 , 78999.95]),
#  array([ 79000.05,  79000.1 ,  79000.15, ..., 139801.85, 139801.9 ,
#         139801.95]),
#  array([139802.05, 139802.1 , 139802.15, ..., 160399.85, 160399.9 ,
#         160399.95]),
#  array([160400.05, 160400.1 , 160400.15, ..., 228297.85, 228297.9 ,
#         228297.95]),
#  array([228298.05, 228298.1 , 228298.15, ..., 248589.85, 248589.9 ,
#         248589.95]),
#  array([248590.05, 248590.1 , 248590.15, ..., 425836.85, 425836.9 ,
#         425836.95]),
#  array([425837.05, 425837.1 , 425837.15, ..., 494799.85, 494799.9 ,
#         494799.95]),
#  array([494800.05, 494800.1 , 494800.15, ..., 562440.85, 562440.9 ,
#         562440.95]),
#  array([562441.05, 562441.1 , 562441.15, ..., 592522.85, 592522.9 ,
#         592522.95]),
#  array([592523.05, 592523.1 , 592523.15, ..., 627200.85, 627200.9 ,
#         627200.95]),
#  array([627201.05, 627201.1 , 627201.15, ..., 685680.85, 685680.9 ,
#         685680.95]),
#  array([685681.05, 685681.1 , 685681.15, ..., 821432.85, 821432.9 ,
#         821432.95]),
#  array([821433.05, 821433.1 , 821433.15, ..., 883490.85, 883490.9 ,
#         883490.95]),
#  array([883491.05, 883491.1 , 883491.15, ..., 963165.85, 963165.9 ,
#         963165.95]),
#  array([ 963166.05,  963166.1 ,  963166.15, ..., 1007821.85, 1007821.9 ,
#         1007821.95]),
#  array([1007822.05, 1007822.1 , 1007822.15, ..., 1083950.85, 1083950.9 ,
#         1083950.95]),
#  array([1083951.05, 1083951.1 , 1083951.15, ..., 1142451.85, 1142451.9 ,
#         1142451.95]),
#  array([1142452.05, 1142452.1 , 1142452.15, ..., 1194428.85, 1194428.9 ,
#         1194428.95]),
#  array([1194429.05, 1194429.1 , 1194429.15, ..., 1267967.85, 1267967.9 ,
#         1267967.95]),
#  array([1267968.05, 1267968.1 , 1267968.15, ..., 1342142.85, 1342142.9 ,
#         1342142.95]),
#  array([1342310.05, 1342310.1 , 1342310.15, ..., 1461933.85, 1461933.9 ,
#         1461933.95]),
#  array([1462165.05, 1462165.1 , 1462165.15, ..., 1514854.85, 1514854.9 ,
#         1514854.95]),
#  array([1514855.05, 1514855.1 , 1514855.15, ..., 1591283.85, 1591283.9 ,
#         1591283.95]),
#  array([1591284.05, 1591284.1 , 1591284.15, ..., 1647494.85, 1647494.9 ,
#         1647494.95]),
#  array([1648197.05, 1648197.1 , 1648197.15, ..., 1720637.85, 1720637.9 ,
#         1720637.95]),
#  array([1721179.05, 1721179.1 , 1721179.15, ..., 1789599.85, 1789599.9 ,
#         1789599.95]),
#  array([1789600.05, 1789600.1 , 1789600.15, ..., 1866389.85, 1866389.9 ,
#         1866389.95]),
#  array([1866390.05, 1866390.1 , 1866390.15, ..., 2036103.85, 2036103.9 ,
#         2036103.95]),
#  array([2036104.05, 2036104.1 , 2036104.15, ..., 2227292.85, 2227292.9 ,
#         2227292.95]),
#  array([2227293.05, 2227293.1 , 2227293.15, ..., 2318278.85, 2318278.9 ,
#         2318278.95]),
#  array([2318279.05, 2318279.1 , 2318279.15, ..., 2403325.85, 2403325.9 ,
#         2403325.95])]
